# %% [markdown]
# <a href="https://colab.research.google.com/github/nicklausmillican/StatisticalRethinkingIISolutions/blob/main/StatisticalRethinkingSolutions2_Ch16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Checking versions of g++ and make
system("g++ --version", intern = TRUE)
system("make --version", intern = TRUE)

# Install g++ and make if needed
system("sudo apt install g++", intern = TRUE)
system("sudo apt install make", intern = TRUE)
# Out:
# [1] "g++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0"
# [2] "Copyright (C) 2021 Free Software Foundation, Inc."
# [3] "This is free software; see the source for copying conditions.  There is NO"
# [4] "warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE."
# [5] ""
# [1] "GNU Make 4.3"
# [2] "Built for x86_64-pc-linux-gnu"
# [3] "Copyright (C) 1988-2020 Free Software Foundation, Inc."
# [4] "License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>"
# [5] "This is free software: you are free to change and redistribute it."
# [6] "There is NO WARRANTY, to the extent permitted by law."
# [1] "Reading package lists..."
# [2] "Building dependency tree..."
# [3] "Reading state information..."
# [4] "g++ is already the newest version (4:11.2.0-1ubuntu1)."
# [5] "g++ set to manually installed."
# [6] "0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded."
# [1] "Reading package lists..."
# [2] "Building dependency tree..."
# ...

# %%
# Install cmdstanr from GitHub
if (!require(cmdstanr)) {
  devtools::install_github("stan-dev/cmdstanr")
}

# Set up CmdStan if it's not already set up
library(cmdstanr)
if (!cmdstanr::cmdstan_version()) {
  cmdstanr::install_cmdstan()
}

# Verify installation
cmdstanr::check_cmdstan_toolchain()
# Out:
# Loading required package: cmdstanr
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘cmdstanr’”
# ...
# numDeriv     (NA     -> 2016.8-1.1) [CRAN]
# matrixStats  (NA     -> 1.5.0     ) [CRAN]
# distribut... (NA     -> 0.5.0     ) [CRAN]
# tensorA      (NA     -> 0.36.2.1  ) [CRAN]
# checkmate    (NA     -> 2.3.2     ) [CRAN]
# abind        (NA     -> 1.4-8     ) [CRAN]
# posterior    (NA     -> 1.6.1     ) [CRAN]
# data.table   (1.17.2 -> 1.17.4    ) [CRAN]
# Installing 8 packages: numDeriv, matrixStats, distributional, tensorA, checkmate, abind, posterior, data.table
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/Rtmp3JZrcU/remotes1ff1711d03b/stan-dev-cmdstanr-c57888e/DESCRIPTION’ ... OK
# * preparing ‘cmdstanr’:
# ...

# %% [markdown]
# IF YOU ENCOUNTER AN ERROR, JUST KEEP RUNNING CODE BELOW.

# %%
# Install CmdStan using cmdstanr
library(cmdstanr)
cmdstanr::install_cmdstan()

# After installation, set the CmdStan path
cmdstan_path <- cmdstanr::cmdstan_path()
cmdstanr::set_cmdstan_path(cmdstan_path)

# Verify the installation
cmdstanr::cmdstan_version()
# Out:
# The C++ toolchain required for CmdStan is setup properly!
#
# * Latest CmdStan release is v2.36.0
#
# * Installing CmdStan v2.36.0 in /root/.cmdstan/cmdstan-2.36.0
#
# * Downloading cmdstan-2.36.0.tar.gz from GitHub...
#
# * Download complete
#
# * Unpacking archive...
#
# * Building CmdStan binaries...
# g++ -Wno-deprecated-declarations -std=c++17 -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes -Wno-class-memaccess      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I stan/lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.4.0 -I stan/lib/stan_math/lib/boost_1.84.0 -I stan/lib/stan_math/lib/sundials_6.1.1/include -I stan/lib/stan_math/lib/sundials_6.1.1/src/sundials    -DBOOST_DISABLE_ASSERTS          -c -MT bin/cmdstan/stansummary.o -MM -E -MG -MP -MF src/cmdstan/stansummary.d src/cmdstan/stansummary.cpp
# cp bin/linux-stanc bin/stanc
# ...

# %%
# Install necessary packages
install.packages(c("coda", "mvtnorm", "devtools", "loo", "dagitty", "shape"))

# Load devtools for GitHub installation
library(devtools)

# Install rethinking from GitHub
devtools::install_github("rmcelreath/rethinking")
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘V8’
#
#
# Loading required package: usethis
#
# ...
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/Rtmp3JZrcU/remotes1ff69078db/rmcelreath-rethinking-ac1b3b2/DESCRIPTION’ ... OK
# * preparing ‘rethinking’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * looking to see if a ‘data/datalist’ file should be added
# * building ‘rethinking_2.42.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(rethinking)
# Out:
# Loading required package: posterior
#
# This is posterior version 1.6.1
#
#
# Attaching package: ‘posterior’
#
#
# The following objects are masked from ‘package:stats’:
#
#     mad, sd, var
#
#
# The following objects are masked from ‘package:base’:
#
#     %in%, match
#
#
# Loading required package: parallel
#
# rethinking (Version 2.42)
#
#
# Attaching package: ‘rethinking’
#
#
# The following object is masked from ‘package:stats’:
#
#     rstudent

# %%
# Test Installation

## Simulate some data for a binary outcome based on a single predictor
n <- 100
x <- rnorm(n)
prob <- 1 / (1 + exp(-x))
y <- rbinom(n, 1, prob)

## Fit a logistic regression using ulam
fit <- ulam(
  alist(
    y ~ bernoulli( p ),
    logit(p) <- a + b*x,
    a ~ normal(0, 1),
    b ~ normal(0, 1)
  ), data = list(x = x, y = y)
)

precis(fit)
# Out:
# Running MCMC with 1 chain, with 1 thread(s) per chain...
#
# Chain 1 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 1 Iteration: 100 / 1000 [ 10%]  (Warmup)
# Chain 1 Iteration: 200 / 1000 [ 20%]  (Warmup)
# Chain 1 Iteration: 300 / 1000 [ 30%]  (Warmup)
# Chain 1 Iteration: 400 / 1000 [ 40%]  (Warmup)
# Chain 1 Iteration: 500 / 1000 [ 50%]  (Warmup)
# Chain 1 Iteration: 501 / 1000 [ 50%]  (Sampling)
# Chain 1 Iteration: 600 / 1000 [ 60%]  (Sampling)
# Chain 1 Iteration: 700 / 1000 [ 70%]  (Sampling)
# Chain 1 Iteration: 800 / 1000 [ 80%]  (Sampling)
# Chain 1 Iteration: 900 / 1000 [ 90%]  (Sampling)
# Chain 1 Iteration: 1000 / 1000 [100%]  (Sampling)
# Chain 1 finished in 0.1 seconds.
#   mean       sd        5.5%       94.5%       rhat     ess_bulk
# a -0.3457412 0.2195408 -0.6968244 -0.02049496 1.003193 302.1354
# b  0.7797090 0.2515921  0.4067534  1.19436735 1.004179 370.1131

# %% [markdown]
# # Chapter 16

# %% [markdown]
# ## Easy

# %% [markdown]
# ### 16E1
#
# What are some disadvantages of generalized linear models (GLMs)?
#
# #### Answer
#
# |Advantages|Disadvantages|
# |----------|-------------|
# |Handles many distributions|But still limited to generic distributions|
# |Keeps results tied to expected value|But results on link scale, which can be hard to interpret|
# |Computationally well supported||
# |Can be extended (GAMs, splines, etc.)|But extension can be a "band-aid" rather than bespoke solution|

# %% [markdown]
# ### 16E2
#
# Can you think of one or more famous scientific models which do not have the additive structure of a GLM?
#
# #### Answer
#
# How about Newton's Law of Gravitation
#
# $$F_g = G \frac{m_1 m_2}{d^2}$$

# %% [markdown]
# ### 16E3
#
# Some models do not look like GLMs at first, but can be transformed through a logarithm into  an additive combination of terms. Do you know any scientific models like this?
#
# #### Answer
#
# We saw an answer to this already in the chapter: the weight-height example (see section 16.1.3).

# %% [markdown]
# ## Medium

# %% [markdown]
# ### 16M1
#
# Modify the cylinder height model, `m16.1`, so that the exponent 3 on height is instead a free  parameter. Do you recover the value of 3 or not? Plot the posterior predictions for the new model.  How do they differ from those of `m16.1`?
#
# #### Answer
# Let's get the data up, build the model.

# %%
data(Howell1)
d <- Howell1
d$w <- d$weight / mean(d$weight)
d$h <- d$height / mean(d$height)

# %% [markdown]
# Let's run both modesl so that we can compare.

# %%
m16.1 <- ulam(
  alist(
    w ~ dlnorm(mu, sigma),
      exp(mu) <- 3.141593 * k * p^2 * h^3,
        p ~ beta(2, 18),
        k ~ exponential(1),
      sigma ~ exponential(1)
  ), data=d,
     iter=1000,
     chains=4,
     cores=4,
     log_lik=TRUE
)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
#
# Chain 1 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 1 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is inf, but must be finite! (in '/tmp/Rtmp2E8P9H/model-13c51669c67.stan', line 23, column 4 to column 32)
#
# Chain 1 If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#
# Chain 1 but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Chain 1
# Chain 2 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 2 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# ...

# %% [markdown]
# For the new model, I'll replace the exponent on `h` with `r`.  I'm not sure what to use as a prior here (which is part of problem 16M2), but I'll assume that `r >= 1` since `w` should generally be greater with higher `h`.

# %%
m16M1 <- ulam(
  alist(
    w ~ dlnorm(mu, sigma),
      exp(mu) <- 3.141593 * k * p^2 * h^r, # insert r for 3, as per question
        p ~ beta(2, 18),
        k ~ exponential(1),
        r ~ normal(1,1),
      sigma ~ exponential(1)
  ), data=d,
     iter=1000,
     chains=4,
     cores=4,
     constraints=list(r="lower=1"),
     log_lik=TRUE
)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
#
# Chain 1 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 1 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is inf, but must be finite! (in '/tmp/Rtmp2E8P9H/model-13c2a284122.stan', line 25, column 4 to column 32)
#
# Chain 1 If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#
# Chain 1 but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Chain 1
#
# Chain 1 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is inf, but must be finite! (in '/tmp/Rtmp2E8P9H/model-13c2a284122.stan', line 25, column 4 to column 32)
#
# ...

# %% [markdown]
# Let's look at the `precis` outputs, with an eye on the new parameter `r`.

# %%
round(precis(m16.1),2)
round(precis(m16M1),2)
# Out:
#       mean sd   5.5% 94.5% rhat ess_bulk
# p     0.30 0.06 0.21 0.41  1.01 495.82
# k     3.82 1.55 1.75 6.63  1.00 495.33
# sigma 0.21 0.01 0.20 0.22  1.01 590.28
#       mean sd   5.5% 94.5% rhat ess_bulk
# p     0.30 0.06 0.22 0.41  1.01  799.81
# k     3.73 1.51 1.78 6.40  1.01  794.31
# r     2.32 0.02 2.29 2.36  1.00 1040.93
# sigma 0.13 0.00 0.12 0.13  1.00 1126.42

# %% [markdown]
# Rather than 3, our estimate for `r` is ~2.3.

# %% [markdown]
# Let's see if PSIS prefers one model over the other.

# %%
round(compare(m16.1, m16M1, func="PSIS"),2)
# Out:
#       PSIS    SE    dPSIS dSE   pPSIS weight
# m16M1 -845.43 36.88   0.0    NA 3.56  1
# m16.1 -310.03 44.24 535.4 54.58 4.02  0

# %% [markdown]
# The free parameter `r` is carrying its weight.

# %% [markdown]
# Let's now plot the posterior.

# %%
post_m16.1 <- extract.samples(m16.1)
post_m16M1 <- extract.samples(m16M1)
# Out:
# List of 4
#  $ p    : num [1:2000, 1] 0.333 0.328 0.269 0.334 0.278 ...
#  $ k    : num [1:2000, 1] 2.72 2.8 4.14 2.72 3.94 ...
#  $ sigma: num [1:2000, 1] 0.201 0.198 0.201 0.209 0.203 ...
#  $ mu   : num [1:2000, 1:544] 0.225 0.225 0.217 0.234 0.235 ...
#  - attr(*, "source")= chr "ulam posterior from object"
# List of 5
#  $ p    : num [1:2000, 1] 0.256 0.386 0.256 0.328 0.161 ...
#  $ k    : num [1:2000, 1] 4.55 1.99 4.52 2.75 11.47 ...
#  $ r    : num [1:2000, 1] 2.34 2.32 2.3 2.3 2.3 ...
#  $ sigma: num [1:2000, 1] 0.125 0.129 0.126 0.13 0.125 ...
#  $ mu   : num [1:2000, 1:544] 0.152 0.145 0.141 0.143 0.142 ...
#  - attr(*, "source")= chr "ulam posterior from object"

# %%
h_seq <- seq(from=0, to=max(d$h), length=50)

m16.1_mu <- with(post_m16.1,
                 log(pi * k * p^2 * h_seq^3))
m16.1_sims <- matrix(data=NA, nrow=2000, ncol=length(h_seq))
for(i in 1:length(h_seq)){
  m16.1_sims[,i] <- rlnorm(n=2000, mean=m16.1_mu[i], sd=post_m16.1$sigma)
}
m16.1_muMeans <- colMeans(m16.1_sims)
m16.1_muHPDIs <- apply(m16.1_sims, 2, HPDI)

m16M1_mu <- with(post_m16M1,
                 log(pi * k * p^2 * h_seq^r))
m16M1_sims <- matrix(data=NA, nrow=2000, ncol=length(h_seq))
for(i in 1:length(h_seq)){
  m16M1_sims[,i] <- rlnorm(n=2000, mean=m16M1_mu[i], sd=post_m16M1$sigma)
}
m16M1_muMeans <- colMeans(m16M1_sims)
m16M1_muHPDIs <- apply(m16M1_sims, 2, HPDI)
# Out:
#       [,1] [,2]         [,3]         [,4]         [,5]         [,6]
#  [1,] 0    1.966831e-05 0.0001857052 0.0003618932 0.0008738996 0.002495121
#  [2,] 0    1.829038e-05 0.0001415606 0.0004750144 0.0011291176 0.001770545
#  [3,] 0    2.261873e-05 0.0001611348 0.0003323764 0.0014128003 0.001791734
#  [4,] 0    1.534460e-05 0.0001785580 0.0006702582 0.0012895195 0.001814806
#  [5,] 0    1.867876e-05 0.0001534615 0.0003758084 0.0009539619 0.002286076
#  [6,] 0    2.209255e-05 0.0001757074 0.0005082523 0.0019291410 0.002530970
#  [7,] 0    1.857475e-05 0.0001558124 0.0007024266 0.0015852381 0.002275392
#  [8,] 0    1.388515e-05 0.0002105205 0.0004118186 0.0011372575 0.002450247
#  [9,] 0    2.558871e-05 0.0001786214 0.0004053617 0.0008874143 0.001732758
# [10,] 0    1.327935e-05 0.0001788975 0.0006453860 0.0008819142 0.002177889
# [11,] 0    1.738174e-05 0.0001763701 0.0005139919 0.0014119836 0.002242432
# [12,] 0    2.080529e-05 0.0001552287 0.0005966169 0.0010548085 0.002301029
# ...

# %%
plot(w ~ h, data=d, col=adjustcolor("blue", 0.5), xlim=c(0, max(d$h)), ylim=c(0, max(d$w)))
lines(m16.1_muMeans ~ h_seq, lty=2, col="red")
lines(m16M1_muMeans ~ h_seq, lty=1)
shade(m16.1_muHPDIs, h_seq, col=adjustcolor("red", 0.2))
shade(m16M1_muHPDIs, h_seq)
# Out:
# plot without title

# %% [markdown]
# The new model does better for shorter individuals, but sorse on taller.

# %% [markdown]
# ### 16M2
#
# Conduct a prior predictive simulation for the cylinder height model. Begin with the priors  in the chapter. Do these produce reasonable prior height distributions? If not, which modifications  do you suggest?
#
# #### Answer

# %%
n_samps <- 100

p <- rbeta(n_samps, 2, 18)
k <- rexp(n_samps, 1)
r <- rnorm(n_samps*2, 1, 1)
  r <- r[r>=1]
  r <- r[1:n_samps]
sigma <- rexp(n_samps, 1)

m16.1_prior <- data.frame(p=p, k=k, sigma=sigma)
m16M1_prior <- data.frame(p=p, k=k, r=r, sigma=sigma)

# %%
plot(w ~ h, data=d, col=adjustcolor("blue", 0.5), xlim=c(0, max(d$h)), ylim=c(0, max(d$w)))
for(i in 1:n_samps){
  with(m16.1_prior,
       curve(pi * k[i] * p[i] * x^3, add=TRUE, lty=1, col=adjustcolor("red", 0.1)))
  with(m16M1_prior,
       curve(pi * k[i] * p[i] * x^r[i], add=TRUE, lty=1, col=adjustcolor("black", 0.1)))
}
# Out:
# plot without title

# %% [markdown]
# Both priors are doing *okay*, but not great.  They're both failing to grow fast enough.  So let's try something a bit different.

# %%
p <- rbeta(n_samps, 3, 18)
k <- rexp(n_samps, 0.5)
r <- rnorm(n_samps*2, 1, 1)
  r <- r[r>=1]
  r <- r[1:n_samps]
sigma <- rexp(n_samps, 1)

m16.1_prior <- data.frame(p=p, k=k, sigma=sigma)
m16M1_prior <- data.frame(p=p, k=k, r=r, sigma=sigma)

plot(w ~ h, data=d, col=adjustcolor("blue", 0.5), xlim=c(0, max(d$h)), ylim=c(0, max(d$w)))
for(i in 1:n_samps){
  with(m16.1_prior,
       curve(pi * k[i] * p[i] * x^3, add=TRUE, lty=1, col=adjustcolor("red", 0.1)))
  with(m16M1_prior,
       curve(pi * k[i] * p[i] * x^r[i], add=TRUE, lty=1, col=adjustcolor("black", 0.1)))
}
# Out:
# plot without title

# %% [markdown]
# ### 16M3
#
# Use prior predictive simulations to investigate the lynx-hare model. Begin with the priors in  the chapter. Which population dynamics do these produce? Can you suggest any improvements to  the priors, on the basis of your simulations?
#
# #### Answer
# Let's get our data up, first.

# %%
data(Lynx_Hare)
d <- Lynx_Hare

# %% [markdown]
# Now we'll simulate the priors as per the book.
#
# Let's start with the example provided in the book.

# %%
sim_lynx_hare <- function( n_steps, init, theta, dt=0.002) {
  L <- rep(NA,n_steps)
  H <- rep(NA,n_steps)
  L[1] <- init[1]
  H[1] <- init[2]
  for (i in 2:n_steps) {
    H[i] <- H[i-1] + dt*H[i-1]*( theta[1] - theta[2]*L[i-1])
    L[i] <- L[i-1] + dt*L[i-1]*( theta[3]*H[i-1] - theta[4])
  }
    return( cbind(L,H))
}

# %%
theta <- c(0.5, 0.05, 0.025, 0.5)
z <- sim_lynx_hare( 1e4, as.numeric(Lynx_Hare[1,2:3]), theta)

plot( z[,2], type="l", ylim=c(0,max(z[,2])), lwd=2, xaxt="n",  ylab="number (thousands)", xlab="")
lines( z[,1], col=rangi2, lwd=2)
mtext( "time", 1)
# Out:
# plot without title

# %% [markdown]
# But now, to get the priors used, we need to call up the model.  Unfortunately, it looks like this:

# %%
data(Lynx_Hare_model)
Lynx_Hare_model
# Out:
# [1] "functions {\n  array[] real dpop_dt(real t, // time\n                       array[] real pop_init,\n                       // initial state {lynx, hares}\n                       array[] real theta, // parameters\n                       array[] real x_r, array[] int x_i) {\n    // unused\n    real L = pop_init[1];\n    real H = pop_init[2];\n    real bh = theta[1];\n    real mh = theta[2];\n    real ml = theta[3];\n    real bl = theta[4];\n    // differential equations\n    real dH_dt = (bh - mh * L) * H;\n    real dL_dt = (bl * H - ml) * L;\n    return {dL_dt, dH_dt};\n  }\n}\ndata {\n  int<lower=0> N; // number of measurement times\n  array[N, 2] real<lower=0> pelts; // measured populations\n}\ntransformed data {\n  array[N - 1] real times_measured; // N-1 because first time is initial state\n  for (i in 2 : N) \n    times_measured[i - 1] = i;\n}\nparameters {\n  array[4] real<lower=0> theta; // { bh, mh, ml, bl }\n  array[2] real<lower=0> pop_init; // initial population state\
# ...

# %% [markdown]
# So I asked ChatGPT to reformat it for us:
#
# ```
# functions {
#   /**
#    * Lotka–Volterra–style predator–prey system
#    *   state = {lynx, hares}
#    *   theta = {bh, mh, ml, bl}
#    */
#   array[] real dpop_dt(
#       real t,                       // time (unused; autonomous system)
#       array[] real pop_init,        // current state
#       array[] real theta,           // parameters
#       array[] real x_r,
#       array[] int  x_i) {
#
#     real L  = pop_init[1];
#     real H  = pop_init[2];
#
#     real bh = theta[1];
#     real mh = theta[2];
#     real ml = theta[3];
#     real bl = theta[4];
#
#     // differential equations
#     real dH_dt = (bh - mh * L) * H;
#     real dL_dt = (bl * H - ml) * L;
#
#     return {dL_dt, dH_dt};          // order matches {lynx, hares}
#   }
# }
#
# data {
#   int<lower = 0>           N;            // number of measurement times
#   array[N, 2] real<lower=0> pelts;       // observed pelts {lynx, hares}
# }
#
# transformed data {
#   array[N - 1] real times_measured;      // integration end‑points (Δt = 1)
#
#   for (i in 2 : N)
#     times_measured[i - 1] = i;
# }
#
# parameters {
#   array[4] real<lower=0>          theta;      // {bh, mh, ml, bl}
#   array[2] real<lower=0>          pop_init;   // initial populations
#   array[2] real<lower=0>          sigma;      // log‑scale SDs
#   array[2] real<lower=0,upper=1>  p;          // trapping proportions
# }
#
# transformed parameters {
#   array[N, 2] real pop;                       // latent populations
#
#   // initial state
#   pop[1, 1] = pop_init[1];
#   pop[1, 2] = pop_init[2];
#
#   // forward simulation
#   pop[2:N, 1:2] =
#     integrate_ode_rk45(
#       dpop_dt,              // system
#       pop_init,             // initial state
#       0,                    // t0
#       times_measured,       // evaluation times
#       theta,                // parameters
#       rep_array(0.0, 0),    // x_r
#       rep_array(0,   0),    // x_i
#       1e-5, 1e-3, 5e2);     // rel_tol, abs_tol, max_steps
# }
#
# model {
#   // --- priors --------------------------------------------------------------
#   theta[{1, 3}] ~ normal(1,     0.5);   // bh, ml (growth rates)
#   theta[{2, 4}] ~ normal(0.05,  0.05);  // mh, bl (interaction rates)
#
#   sigma     ~ exponential(1);
#   pop_init  ~ lognormal(log(10), 1);
#   p         ~ beta(40, 200);
#
#   // --- likelihood ----------------------------------------------------------
#   for (t in 1 : N)
#     for (k in 1 : 2)
#       pelts[t, k] ~ lognormal(log(pop[t, k] * p[k]), sigma[k]);
# }
#
# generated quantities {
#   array[N, 2] real pelts_pred;
#
#   for (t in 1 : N)
#     for (k in 1 : 2)
#       pelts_pred[t, k] =
#         lognormal_rng(log(pop[t, k] * p[k]), sigma[k]);
# }
#
# ```

# %% [markdown]
# We can see that the priors are
#
# ```
# theta[{1, 3}] ~ normal(1,     0.5);   // bh, ml (growth rates)
# theta[{2, 4}] ~ normal(0.05,  0.05);  // mh, bl (interaction rates)
# ```
#
# So let's simulate these and plug them back into our `sim_lynx_hare` function.

# %%
N=9
theta <- matrix(data=NA, nrow=N, ncol=4)
theta[,1] <- rnorm(N, 1, 0.5)
theta[,2] <- rnorm(N, 0.05, 0.05)
theta[,3] <- rnorm(N, 1, 0.5)
theta[,4] <- rnorm(N, 0.05, 0.05)

# %%
par(mfrow=c(3,3))

for(i in 1:N){
  z <- sim_lynx_hare( 1e4, as.numeric(Lynx_Hare[1,2:3]), theta[i,])
  max_y <- max(z)
  if(max_y==Inf) max_y <- 1000000
  plot(NULL, xaxt="n",  ylab="", xlab="", xlim=c(0, 10000), ylim=c(0, max_y))
  lines(z[,2], col="black", lwd=2)
  lines(z[,1], col=rangi2, lwd=2)
}
# Out:
# plot without title

# %% [markdown]
# Let's use the example in the book to readjust these priors.

# %%
N=9
theta <- matrix(data=NA, nrow=N, ncol=4)
theta[,1] <- rnorm(N, 0.5, 0.1)
theta[,2] <- rnorm(N, 0.05, 0.01)
theta[,3] <- rnorm(N, 0.025, 0.01)
theta[,4] <- rnorm(N, 0.5, 0.01)

par(mfrow=c(3,3))
for(i in 1:N){
  z <- sim_lynx_hare( 1e4, as.numeric(Lynx_Hare[1,2:3]), theta[i,])
  max_y <- max(z)
  if(max_y==Inf) max_y <- 1000000
  plot(NULL, xaxt="n",  ylab="", xlab="", xlim=c(0, 10000), ylim=c(0, max_y))
  lines(z[,2], col="black", lwd=2)
  lines(z[,1], col=rangi2, lwd=2)
}
# Out:
# plot without title

# %% [markdown]
# ### 16M4
#
# Modify the cylinder height model to use a sphere instead of a cylinder. What choices do you  have to make now? Is this a better model, on a predictive basis? Why or why not?
#
# #### Answer
# In the cylinder example, we estimated the volume as $V_{cylinder}=\pi r^2 h = \pi (ph)^2 h = \pi p^2 h^3$, where weight was proportional thereto by $W \approx kV_{cylinder}$.
#
# For a sphere, we need $V=\frac{4}{3} \pi r^3 = \frac{4}{3} \pi (\frac{h}{2})^3$, setting weight proportional thereto via $W \approx jV_{sphere}$.
#
# So now let's run the cylinder and sphere models.

# %%
data(Howell1)
d <- Howell1
d$w <- d$weight / mean(d$weight)
d$h <- d$height / mean(d$height)

# %%
mCylinder <- ulam(
  alist(
    w ~ dlnorm(mu, sigma),
      exp(mu) <- 3.141593 * k * p^2 * h^3,
        p ~ beta(2, 18),
        k ~ exponential(1),
      sigma ~ exponential(1)
  ), data=d,
     iter=1000,
     chains=4,
     cores=4,
     constraints=list(r="lower=1"),
     log_lik=TRUE
)

mSphere <- ulam(
  alist(
    w ~ dlnorm(mu, sigma),
      exp(mu) <- j * (4/3) * 3.141593 * (h/2)^3,
        j ~ exponential(1),
      sigma ~ exponential(1)
  ), data=d,
     iter=1000,
     chains=4,
     cores=4,
     constraints=list(r="lower=1"),
     log_lik=TRUE
)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
#
# Chain 1 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 1 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -inf, but must be finite! (in '/tmp/Rtmprx5trP/model-e414665b91.stan', line 23, column 4 to column 32)
#
# Chain 1 If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#
# Chain 1 but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Chain 1
# Chain 2 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 2 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# ...

# %% [markdown]
# Now let's use PSIS to compare these.

# %%
compare(mCylinder, mSphere, func=PSIS)
# Out:
#           PSIS      SE       dPSIS     dSE      pPSIS    weight
# mSphere   -310.3091 44.29351 0.0000000       NA 3.799473 0.5176584
# mCylinder -310.1677 44.32504 0.1413262 0.064694 3.946713 0.4823416

# %% [markdown]
# These are basically identical.

# %% [markdown]
# ## Hard

# %% [markdown]
# ### 16H1
#
# Modify the Panda nut opening model so that male and female chimpanzees have different maximum adult body mass. The sex variable in data(`Panda_nuts`) provides the information you  need. Be sure to incorporate the fact that you know, prior to seeing the data, that males are on average larger than females at maturity.
#
# #### Answer
#
# Let's start by loading the data as per the chapter.

# %%
data(Panda_nuts)
d <- Panda_nuts
dat_list <- list(
  n = as.integer(Panda_nuts$nuts_opened),
  age = Panda_nuts$age/ max(Panda_nuts$age),
  seconds = Panda_nuts$seconds)

# %% [markdown]
# We also need to add an indexing variable to distinguish between male and females.

# %%
dat_list$sex_id <- ifelse(d$sex=="m", 1, 2)

# %% [markdown]
# Now let's adjust the model from the chapter.

# %%
m16H1 <- ulam(
  alist(
    n ~ poisson( lambda),
    lambda <- seconds*phi[sex_id]*(1-exp(-k*age))^theta,
    phi[sex_id] ~ lognormal( log(1), 0.1),
    k ~ lognormal( log(2), 0.25),
    theta ~ lognormal( log(5), 0.25)
  ), data=dat_list,
  chains=4, cores=4, iter=1000)

# %% [markdown]
# Upon seeing this, I realize that there isn't a straightforward way to "...incorporate the fact that you know...that males are on average larger than females at maturity" with indexing variable.  So I'm going to change this to using a dummy variable.

# %%
dat_list$sex_id <- ifelse(d$sex=="m", 1, 0)

m16H1 <- ulam(
  alist(
    n ~ poisson( lambda),
      lambda <- seconds*(phi*(1 + sex_id*p))*(1-exp(-k*age))^theta,  # p is the proportion by which m >= f
        phi ~ lognormal( log(1), 0.1),
        p ~ dexp(1),
        k ~ lognormal( log(2), 0.25),
        theta ~ lognormal( log(5), 0.25)
  ), data=dat_list,
     chains=4, cores=4, iter=1000)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
#
# Chain 1 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 1 Iteration: 100 / 1000 [ 10%]  (Warmup)
# Chain 2 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 2 Iteration: 100 / 1000 [ 10%]  (Warmup)
# Chain 2 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# Chain 2 Exception: poisson_lpmf: Rate parameter[3] is -nan, but must be nonnegative! (in '/tmp/RtmprisEzn/model-125171ea8ae.stan', line 23, column 4 to column 26)
#
# Chain 2 If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#
# Chain 2 but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Chain 2
# Chain 3 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 3 Iteration: 100 / 1000 [ 10%]  (Warmup)
# ...

# %%
round(precis(m16H1),2)
# Out:
#       mean sd   5.5% 94.5% rhat ess_bulk
# phi   0.60 0.05 0.53  0.67 1.01 760.60
# p     0.68 0.14 0.48  0.91 1.00 835.11
# k     5.14 0.67 4.05  6.17 1.01 655.77
# theta 7.57 1.84 4.94 10.71 1.01 668.68

# %% [markdown]
# Now let's recreate the plots from the chapter.

# %%
post <- extract.samples(m16H1)

plot(NULL, xlim=c(0,1), ylim=c(0,1.5), xlab="age", ylab="nuts/sec", xaxt="n")
  at <- c(0.00, 0.25, 0.50, 0.75, 1.00, 1.25, 1.50)
  axis(1, at=at, labels=round(at*max(Panda_nuts$age)))

pts <- dat_list$n / dat_list$seconds
point_size <- normalize(dat_list$seconds)
points(jitter(dat_list$age), pts, lwd=2, cex=point_size*3,
       col=ifelse(dat_list$sex_id==1, "skyblue", "pink3"))

for(i in 1:30){
  with(post,
       curve(phi[i]*(1 + p[i]) * (1-exp(-k[i]*x))^theta[i], add=TRUE, col="skyblue"))

  with(post,
       curve(phi[i] * (1-exp(-k[i]*x))^theta[i], add=TRUE, col="pink3"))
}
# Out:
# plot without title

# %% [markdown]
# ### 16H2
#
# Now return to the Panda nut model and try to incorporate individual differences. There are  two parameters, $ϕ$ and $k$, which plausibly vary by individual. Pick one of these, allow it to vary by individual, and use partial pooling to avoid overfitting. The variable chimpanzee in `data(Panda_nuts)`  tells you which observations belong to which individuals.
#
# #### Answer

# %%
# Run data from 16H1
dat_list$id <- d$chimpanzee

# %%
m16H2 <- ulam(
  alist(
    n ~ poisson( lambda),
      lambda <- seconds*(phi[id]*(1 + sex_id*p))*(1-exp(-k*age))^theta,
        phi[id] ~ lognormal( log(1), 0.1),
        p ~ dexp(1),
        k ~ lognormal( log(2), 0.25),
        theta ~ lognormal( log(5), 0.25)
  ), data=dat_list,
     chains=4, cores=4, iter=1000)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
#
# Chain 1 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 1 Iteration: 100 / 1000 [ 10%]  (Warmup)
# Chain 1 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# Chain 1 Exception: poisson_lpmf: Rate parameter[1] is -nan, but must be nonnegative! (in '/tmp/RtmprisEzn/model-1254b22aed7.stan', line 23, column 4 to column 26)
#
# Chain 1 If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#
# Chain 1 but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Chain 1
# Chain 2 Iteration:   1 / 1000 [  0%]  (Warmup)
# Chain 2 Iteration: 100 / 1000 [ 10%]  (Warmup)
# Chain 2 Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#
# ...

# %%
round(precis(m16H2, depth=2),2)
# Out:
#         mean sd   5.5% 94.5% rhat ess_bulk
# phi[1]  0.97 0.09 0.83 1.13  1.00 3793.98
# phi[2]  0.99 0.10 0.84 1.16  1.00 4157.91
# phi[3]  0.97 0.09 0.83 1.13  1.00 3643.19
# phi[4]  0.96 0.09 0.82 1.11  1.00 3046.78
# phi[5]  0.97 0.09 0.83 1.12  1.00 4462.95
# phi[6]  0.88 0.07 0.77 0.99  1.01 3232.29
# phi[7]  0.87 0.08 0.75 1.00  1.00 3902.57
# phi[8]  1.01 0.10 0.85 1.18  1.00 3612.60
# phi[9]  1.94 0.12 1.76 2.13  1.00 3192.19
# phi[10] 0.88 0.07 0.78 0.99  1.00 3107.33
# phi[11] 0.93 0.09 0.79 1.08  1.00 3542.50
# phi[12] 1.11 0.09 0.97 1.27  1.01 4343.14
# phi[13] 0.90 0.09 0.77 1.04  1.00 4039.03
# phi[14] 1.07 0.11 0.91 1.25  1.00 3734.31
# phi[15] 1.06 0.11 0.91 1.23  1.00 3531.73
# phi[16] 0.95 0.09 0.82 1.11  1.00 3866.13
# phi[17] 0.92 0.09 0.79 1.08  1.00 3694.67
# phi[18] 0.99 0.10 0.83 1.16  1.00 3786.23
# phi[19] 1.17 0.09 1.05 1.32  1.00 2810.90
# phi[20] 0.77 0.05 0.68 0.85  1.00 2754.65
# phi[21] 1.00 0.10 0.85 1.16  1.00 3823.03
# ...

# %% [markdown]
# ### 16H3
#
# The chapter asserts that a typical, geocentric time series model might be one that uses lag variables. Here you’ll fit such a model and compare it to the ODE model in the chapter. An autoregressive time series uses earlier values of the state variables to predict new values of the same variables. These  earlier values are called *lag variables*. You can construct the lag variables here with:
#
# ```
# data(Lynx_Hare)
# dat_ar1 <- list(
#   L = Lynx_Hare$Lynx[2:21],
#   L_lag1 = Lynx_Hare$Lynx[1:20],
#   H = Lynx_Hare$Hare[2:21],
#   H_lag1 = Lynx_Hare$Hare[1:20])
# ```
#
# Now you can use `L_lag1` and `H_lag1` as predictors of the outcomes `L` and `H`. Like this:
#
# $$L_t ∼ \text{Log-Normal}(\log µ_{L,t}, σ_L)$$
# $$µ_{L,t} = α_L + β_{LL} L_{t−1} + β_{LH} H_{t−1}$$
# $$H_t ∼ \text{Log-Normal}(\log µ_{H,t}, σ_H)$$
# $$µ_{H,t} = α_H + β_{HH} H_{t−1} + β_{HL} L_{t−1}$$
#
# where $L_{t−1}$ and $H_{t−1}$ are the lag variables. Use `ulam()` to fit this model. Be careful of the priors of the $α$ and $β$ parameters. Compare the posterior predictions of the autoregressive model to the ODE  model in the chapter. How do the predictions differ? Can you explain why, using the structures of  the models?
#
# #### Answer

# %% [markdown]
# Let's first run the ODE, since we'll need to compare the autoregressive model to it.

# %%
data(Lynx_Hare)
data(Lynx_Hare_model)
dat_list <- list(
  N = nrow(Lynx_Hare),
  pelts = Lynx_Hare[,2:3]
)

m16.5 <- stan(model_code=Lynx_Hare_model,
              data=dat_list,
              chains=4,
              cores=4,
              iter=1000,
              control=list(adapt_delta=0.95))
# Out:
# Warning in '/tmp/Rtmp3JZrcU/model-1ff2d7a4f6c.stan', line 39, column 22: integrate_ode_rk45
#     is deprecated and will be removed in Stan 3.0. Use ode_rk45 instead.
#     The new interface is slightly different, see:
#     https://mc-stan.org/users/documentation/case-studies/convert_odes.html
#
#
# In file included from stan/lib/stan_math/lib/boost_1.84.0/boost/concept/assert.hpp:35,
#                  from stan/lib/stan_math/lib/boost_1.84.0/boost/concept_check.hpp:20,
#                  from stan/lib/stan_math/lib/boost_1.84.0/boost/range/concepts.hpp:19,
#                  from stan/lib/stan_math/lib/boost_1.84.0/boost/range/size_type.hpp:20,
#                  from stan/lib/stan_math/lib/boost_1.84.0/boost/range/size.hpp:21,
#                  from stan/lib/stan_math/lib/boost_1.84.0/boost/range/functions.hpp:20,
#                  from stan/lib/stan_math/lib/boost_1.84.0/boost/range.hpp:18,
# ...

# %%
round(precis(m16.5, depth=2),2)
# Out:
# 84 matrix parameters hidden. Use depth=3 to show them.
#             mean   sd    5.5%   94.5%  rhat ess_bulk
# theta[1]      0.53  0.06   0.44   0.63 1.00  706.95
# theta[2]      0.00  0.00   0.00   0.01 1.01  854.51
# theta[3]      0.81  0.10   0.67   0.97 1.00  722.21
# theta[4]      0.00  0.00   0.00   0.01 1.00  730.21
# pop_init[1]  36.56  6.33  27.38  47.18 1.01 1123.40
# pop_init[2] 142.46 23.62 108.38 183.67 1.00  928.02
# sigma[1]      0.27  0.05   0.20   0.35 1.00 2013.38
# sigma[2]      0.25  0.04   0.19   0.33 1.01 1778.11
# p[1]          0.17  0.02   0.14   0.21 1.00 1165.12
# p[2]          0.18  0.03   0.14   0.22 1.00  943.41

# %% [markdown]
# Now let's run the code block to get our lag variables, and build an autoregressive model.

# %%
dat_ar1 <- list(
  L = Lynx_Hare$Lynx[2:21],
  L_lag1 = Lynx_Hare$Lynx[1:20],
  H = Lynx_Hare$Hare[2:21],
  H_lag1 = Lynx_Hare$Hare[1:20])

m16H3 <- ulam(
  alist(
    L ~ dlnorm(log(mu_L), sigma_L),
      mu_L <- a_L + beta_LL*L_lag1 + beta_LH*H_lag1,
        a_L ~ dnorm(0,1),
        beta_LL ~ dnorm(1,1),
        beta_LH ~ dnorm(1,1),
      sigma_L ~ dexp(1),

    H ~ dlnorm(log(mu_H), sigma_H),
      mu_H <- a_H + gamma_HH*H_lag1 + gamma_HL*L_lag1,
        a_H ~ dnorm(0,1),
        gamma_HH ~ dnorm(1,1),
        gamma_HL ~ dnorm(-1,1),
      sigma_H ~ dexp(1)
), data=dat_ar1,
   chains=4,
   cores=4,
   iter=1000)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
# Chain 1 Rejecting initial value:
#
# Chain 1   Error evaluating the log probability at the initial value.
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff40410524.stan', line 27, column 4 to column 41)
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff40410524.stan', line 27, column 4 to column 41)
#
# Chain 1 Rejecting initial value:
#
# Chain 1   Error evaluating the log probability at the initial value.
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff40410524.stan', line 27, column 4 to column 41)
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff40410524.stan', line 27, column 4 to column 41)
#
# Chain 1 Rejecting initial value:
#
# ...

# %%
round(precis(m16H3),2)
# Out:
#          mean  sd   5.5%  94.5% rhat ess_bulk
# a_L      -0.82 0.91 -2.27 0.64  1.00 1858.60
# beta_LL   0.53 0.09  0.40 0.67  1.00 1481.76
# beta_LH   0.25 0.05  0.18 0.33  1.00 1467.40
# sigma_L   0.31 0.06  0.23 0.41  1.01 1839.89
# a_H       0.71 0.99 -0.88 2.28  1.01 1829.13
# gamma_HH  1.15 0.17  0.89 1.43  1.00 1263.17
# gamma_HL -0.17 0.11 -0.34 0.02  1.00 1353.26
# sigma_H   0.45 0.08  0.34 0.60  1.00 1890.82

# %% [markdown]
# Now we'll plot the posteriors from the 2 models.

# %%
par(mfrow=c(1,2))

# ODE
post <- extract.samples(m16.5)
pelts <- dat_list$pelts
plot(1:21, pelts[,2], pch=16, ylim=c(0,120), xlab="year",  ylab="thousands of pelts", xaxt="n", main="ODE")
at <- c(1,11,21)
axis(1, at=at, labels=Lynx_Hare$Year[at])
points( 1:21, pelts[,1], col=rangi2, pch=16)
#21 time series from posterior
for (s in 1:21) {
  lines(1:21, post$pelts_pred[s,,2], col=col.alpha("black",0.2), lwd=2)
  lines(1:21, post$pelts_pred[s,,1], col=col.alpha(rangi2,0.3), lwd=2)
  }
#text labels
text(17, 90, "Lepus", pos=2)
text(19, 50, "Lynx", pos=2, col=rangi2)

# Autoregressive
post <- extract.samples(m16H3)
plot(dat_ar1$H, pch=16, ylim=c(0,120), xlab="year", ylab="thousands of pelts", xaxt="n", main="AR")
at <- c(1,11,21)
axis(1, at=at, labels=Lynx_Hare$Year[at])
points(dat_ar1$L , pch=16 , col=rangi2 )
#21 time series from posterior
mu <- link(m16H3)
for(s in 1:20) {
  lines(1:20 , mu$mu_H[s,] , col=col.alpha("black",0.2) , lwd=2 )
  lines(1:20 , mu$mu_L[s,] , col=col.alpha(rangi2,0.3) , lwd=2 )
}
#text labels
text(17, 90, "Lepus", pos=2)
text(19, 50, "Lynx", pos=2, col=rangi2)
# Out:
# Plot with title “AR”

# %% [markdown]
# The `AR` model is doing worse at predicting the data.
#
# In the next question, we'll modify it to include 2 lag variables.

# %% [markdown]
# ### 16H4
#
# Adapt the autoregressive model to use a two-step lag variable. This means that $L_{t−2}$ and $H_{t−2}$,  in addition to $L_{t−1}$ and $H_{t−1}$, will appear in the equation for $µ$. This implies that prediction depends  upon not only what happened just before now, but also on what happened two time steps ago. How  does this model perform, compared to the ODE model?
#
# #### Answer
# Continuing from 16H3, let's modify the lag model.

# %%
dat_ar2 <- list(
  L = Lynx_Hare$Lynx[3:21],
  L_lag1 = Lynx_Hare$Lynx[2:20],
  L_lag2 = Lynx_Hare$Lynx[1:19],
  H = Lynx_Hare$Hare[3:21],
  H_lag1 = Lynx_Hare$Hare[2:20],
  H_lag2 = Lynx_Hare$Hare[1:19]) # Shift all data by 1

m16H4 <- ulam(
  alist(
    L ~ dlnorm(log(mu_L), sigma_L),
      mu_L <- a_L + beta_LL*L_lag1 + beta_LL2*L_lag2 +
                    beta_LH*H_lag1 + beta_LH2*H_lag2,
        a_L ~ dnorm(0,1),
        beta_LL ~ dnorm(1,1),
        beta_LL2 ~ dnorm(1,1),
        beta_LH ~ dnorm(1,1),
        beta_LH2 ~ dnorm(1,1),
      sigma_L ~ dexp(1),

    H ~ dlnorm(log(mu_H), sigma_H),
      mu_H <- a_H + gamma_HH*H_lag1 + gamma_HH2*H_lag2 +
                    gamma_HL*L_lag1 + gamma_HL2*L_lag2,
        a_H ~ dnorm(0,1),
        gamma_HH ~ dnorm(1,1),
        gamma_HH2 ~ dnorm(1,1),
        gamma_HL ~ dnorm(-1,1),
        gamma_HL2 ~ dnorm(1,1), # If the 1st dif is neg, then the 2nd is pos
      sigma_H ~ dexp(1)
), data=dat_ar2,
   chains=4,
   cores=4,
   iter=1000)
# Out:
# Running MCMC with 4 parallel chains, with 1 thread(s) per chain...
# Chain 1 Rejecting initial value:
#
# Chain 1   Error evaluating the log probability at the initial value.
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff1b723f59.stan', line 35, column 4 to column 41)
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff1b723f59.stan', line 35, column 4 to column 41)
#
# Chain 1 Rejecting initial value:
#
# Chain 1   Error evaluating the log probability at the initial value.
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff1b723f59.stan', line 35, column 4 to column 41)
#
# Chain 1 Exception: lognormal_lpdf: Location parameter[1] is -nan, but must be finite! (in '/tmp/Rtmp3JZrcU/model-1ff1b723f59.stan', line 35, column 4 to column 41)
#
# Chain 1 Rejecting initial value:
#
# ...

# %%
round(precis(m16H4),2)
# Out:
#           mean  sd   5.5%  94.5% rhat ess_bulk
# a_L       -0.40 0.95 -1.92  1.10 1    1738.14
# beta_LL    0.83 0.29  0.37  1.29 1     870.23
# beta_LL2  -0.16 0.13 -0.36  0.04 1    1029.94
# beta_LH    0.33 0.15  0.09  0.57 1     978.94
# beta_LH2  -0.14 0.24 -0.52  0.24 1     879.69
# sigma_L    0.30 0.06  0.23  0.41 1    1459.12
# a_H        0.39 0.96 -1.13  1.94 1    1969.52
# gamma_HH   0.85 0.27  0.42  1.28 1    1003.25
# gamma_HH2  0.50 0.45 -0.19  1.22 1     922.81
# gamma_HL  -1.14 0.54 -2.03 -0.28 1     926.85
# gamma_HL2  0.55 0.23  0.21  0.93 1    1029.58
# sigma_H    0.40 0.08  0.30  0.54 1     978.59

# %% [markdown]
# Now let's plot again

# %%
par(mfrow=c(1,3))

# ODE
post <- extract.samples(m16.5)
pelts <- dat_list$pelts
plot(1:21, pelts[,2], pch=16, ylim=c(0,120), xlab="year",  ylab="thousands of pelts", xaxt="n", main="ODE")
at <- c(1,11,21)
axis(1, at=at, labels=Lynx_Hare$Year[at])
points(1:21, pelts[,1], col=rangi2, pch=16)
#21 time series from posterior
for (s in 1:21) {
  lines(1:21, post$pelts_pred[s,,2], col=col.alpha("black",0.2), lwd=2)
  lines(1:21, post$pelts_pred[s,,1], col=col.alpha(rangi2,0.3), lwd=2)
  }
#text labels
text(17, 90, "Lepus", pos=2)
text(19, 50, "Lynx", pos=2, col=rangi2)

# AR1
post <- extract.samples(m16H3)
plot(dat_ar1$H, pch=16, ylim=c(0,120), xlab="year", ylab="thousands of pelts", xaxt="n", main="AR1")
at <- c(1,11,21)
axis(1, at=at, labels=Lynx_Hare$Year[at])
points(dat_ar1$L , pch=16 , col=rangi2 )
#21 time series from posterior
mu <- link(m16H3)
for(s in 1:20) {
  lines(1:20 , mu$mu_H[s,] , col=col.alpha("black",0.2) , lwd=2)
  lines(1:20 , mu$mu_L[s,] , col=col.alpha(rangi2,0.3) , lwd=2)
}
#text labels
text(17, 90, "Lepus", pos=2)
text(19, 50, "Lynx", pos=2, col=rangi2)

# AR2
post <- extract.samples(m16H4)
plot(dat_ar2$H, pch=16, ylim=c(0,120), xlab="year", ylab="thousands of pelts", xaxt="n", main="AR2")
at <- c(1,11,21)
axis(1, at=at, labels=Lynx_Hare$Year[at])
points(dat_ar2$L , pch=16 , col=rangi2)
#21 time series from posterior
mu <- link(m16H4)
for(s in 1:19) {
  lines(1:19, mu$mu_H[s,] , col=col.alpha("black",0.2) , lwd=2)
  lines(1:19, mu$mu_L[s,] , col=col.alpha(rangi2,0.3) , lwd=2)
}
#text labels
text(17, 90, "Lepus", pos=2)
text(19, 50, "Lynx", pos=2, col=rangi2)
# Out:
# Plot with title “AR2”

# %% [markdown]
# Doesn't seem much better.
